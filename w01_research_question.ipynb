# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafaelsayedk71-sys/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mustafaelsayedk71-sys/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Lane: Freestyle (Content-Type & Performance Optimization)
# Why: Understanding how different content types affect CTR is essential for production decisions.
# As someone looking to build backend tools and platforms, knowing which content drives
# the best user action helps optimize web resources and structure application schemas effectively.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: Which types of content should we prioritize developing or updating on the platform?
# Action: Content managers and developers will re-allocate layout architecture and backend caching to favor high-performing content.
# Cost of a wrong call: Wasting development hours, database storage, and cloud computing costs on maintaining types of content that users don't engage with.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess
import pandas as pd

# 1. إعداد البيئة وجلب البيانات من المستودع الأصلي داخل Colab
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.exists(REPO_DIR):  # تم إصلاح السطر هنا
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    if os.getcwd().endswith("notebooks") or "work" in os.getcwd():
        os.chdir("../..")
    if REPO_DIR in os.listdir() and os.getcwd() != os.path.join(os.getcwd(), REPO_DIR):
        os.chdir(REPO_DIR)

# 2. قراءة البيانات من المسار المعتمد بعد ضبط الـ Root
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 3. استخراج الأرقام الحقيقية المطلوبة
active_df = df[df["impressions_90d"] > 0]
total_rows = len(df)
active_rows = len(active_df)
avg_search_volume = df["search_volume"].mean()

print(f"1. Total dataset rows: {total_rows}")
print(f"2. Active rows (Impressions > 0): {active_rows}")
print(f"3. Global Average Search Volume: {avg_search_volume:.2f}")
# Out:
# 1. Total dataset rows: 30000
# 2. Active rows (Impressions > 0): 30000
# 3. Global Average Search Volume: 158.88

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What I can claim: I can provide decision-support based on observed directional patterns in user engagement across historical data.
# What I CANNOT claim: I cannot provide causal proof of why certain patterns happen, and I am not predicting or reverse-engineering Google's core ranking algorithms.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
